# %% [markdown]
# # Hello

# %% [markdown]
# ## Walkthru sample notebook

# %% [markdown]
# Here is how I calculate `2+2`:

# %%
2+2
# Out:
# 4

# %%
from numpy import *

# %% [markdown]
# Here is how I calculate `sin`:

# %%
a = array([1.0, pi/2])
sin(a)
# Out:
# array([0.84147098, 1.        ])
